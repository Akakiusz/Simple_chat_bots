# %% [markdown]
# ## Project description (in build)
#
# <span style="color:white;
#   background:#009E60;
#   padding:4px 10px">
#   Cofbot
# </span>
#
# ### Model Based Reflex Agent
# A model based reflex agent is an upgrade from a simple reflex agent. The key difference is that it keeps track of the current state of the world — it has memory. This means it can make decisions based not just on the current input, but also on what happened before.
