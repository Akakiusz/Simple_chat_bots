# %% [markdown]
# ## Project description (in build)
#
# <span style="color:white;
#   background:#93A9B5;
#   padding:4px 10px">
#   Goal based
# </span>
#
# ### Goal Based Agent
# A goal based reflex agent is
